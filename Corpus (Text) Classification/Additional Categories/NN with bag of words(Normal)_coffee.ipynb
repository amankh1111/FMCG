# %%
import xgboost as xgb
import numpy as np
import pandas as pd
import time
import pickle
import os
from math import log
import matplotlib.pyplot as plt
from keras.optimizers import Adam

import sklearn
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV,KFold, ParameterGrid,StratifiedKFold, cross_val_score

from sklearn import metrics 
from sklearn.metrics import confusion_matrix, precision_recall_curve, average_precision_score, brier_score_loss, f1_score, log_loss,auc,roc_curve,auc

from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.ensemble import RandomForestClassifier

from sklearn.decomposition import PCA
#from sklearn.utils.fixes import signature

from datetime import datetime

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
os.chdir(r"C:\Users\aman.khatri91425\Desktop\HomeCredit\Bigdata\Corpus Classification")

# %%
df = pd.read_excel(os.getcwd()+r"\Data Files\New Categories\Corpus_Coffee.xlsx", encoding = 'unicode_escape')

# %%
df.head()
# Out:
#   spend_group spend_cat_raw_l1           spend_cat_raw_l2  \
# 0         Raw           Coffee  Cof/ Arabica Green Coffee
# 1         Raw           Coffee  Cof/ Arabica Green Coffee
# 2         Raw           Coffee  Cof/ Arabica Green Coffee
# 3         Raw           Coffee  Cof/ Arabica Green Coffee
# 4         Raw           Coffee  Cof/ Arabica Green Coffee
#
#                spend_cat_raw_l3              spend_cat_raw_l4  \
# 0  Cof/Ara/ Washed Unclassified  Cof/Ara/ Washed Unclassified
# 1  Cof/Ara/ Washed Unclassified                  Not assigned
# 2  Cof/Ara/ Washed Unclassified                  Not assigned
# 3  Cof/Ara/ Washed Unclassified                  Not assigned
# 4  Cof/Ara/ Washed Unclassified                  Not assigned
#
#                spend_cat_raw_l5 material_group_master_data  \
# 0  Cof/Ara/ Washed Unclassified                        R43
# 1                  Not assigned                        R43
# 2                  Not assigned                        R43
# 3                  Not assigned                        R43
# 4                  Not assigned                        R43
#
#   material_group_master_data_desc  material                material_desc  ...  \
# 0                          Coffee  43927387     Instant Coffee 103500950  ...
# 1                          Coffee  43444566  Coffee Green WsA Pf-ID Java  ...
# 2                          Coffee  43444566  Coffee Green WsA Pf-ID Java  ...
# 3                          Coffee  43444566  Coffee Green WsA Pf-ID Java  ...
# 4                          Coffee  43444569     Coffee Green WsA Pf-Peru  ...
#
#   account_number account_number_desc cost_center   cost_center_desc  \
# 0         N001/#   N001/Not assigned      0020/#  0020/Not assigned
# 1         N001/#   N001/Not assigned      0068/#  0068/Not assigned
# 2         N001/#   N001/Not assigned      0068/#  0068/Not assigned
# 3         N001/#   N001/Not assigned      0068/#  0068/Not assigned
# 4         N001/#   N001/Not assigned      0068/#  0068/Not assigned
#
#    invoice_amount invoice_amt_rep_curr_mth_rate                   label_l2  \
# 0         3552.00                       4044.92  Cof/ Arabica Green Coffee
# 1      3399730.47                    3399730.47  Cof/ Arabica Green Coffee
# 2       456898.47                     456898.47  Cof/ Arabica Green Coffee
# 3       481257.36                     481257.36  Cof/ Arabica Green Coffee
# 4       252424.25                     252424.25  Cof/ Arabica Green Coffee
#
#                        label_l3                      label_l4  \
# 0  Cof/Ara/ Washed Unclassified  Cof/Ara/ Washed Unclassified
# 1  Cof/Ara/ Washed Unclassified                           NaN
# 2  Cof/Ara/ Washed Unclassified                           NaN
# 3  Cof/Ara/ Washed Unclassified                           NaN
# 4  Cof/Ara/ Washed Unclassified                           NaN
#
#                        label_l5
# 0  Cof/Ara/ Washed Unclassified
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
# [5 rows x 35 columns]

# %%
df.label_l2.value_counts()
# Out:
# Cof/ Arabica Green Coffee    697
# Cof/ Robusta Green Coffee    462
# Cof/ Soluble                  11
# Cof/Oil,Aroma & Extract        6
# Cof/ Blended Green Coffee      6
# Cof/ Roast & Ground            2
# Name: label_l2, dtype: int64

# %%
df.label_l2= np.where((df.label_l2 == 'Cof/ Roast & Ground') | (df.label_l2 == 'Cof/ Blended Green Coffee') | 
                      (df.label_l2 == 'Cof/Oil,Aroma & Extract') | (df.label_l2 == 'Cof/ Soluble')
         , "OTHERS",df.label_l2)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(df["label_l2"])
df["label_l2_enc"]=le.transform(df["label_l2"])


# df["label_l2_enc"]=pd.get_dummies(df['label_l2']).values

# %%
x_column = ["material_descr_from_po","vendor_desc","account_number_desc","cost_center_desc"]
y_column = ["label_l2_enc"]
seed = 10

# %%
X_train_1, X_test, y_train_1, y_test = train_test_split(df[x_column], df[y_column], test_size=0.2, random_state=seed)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_1, y_train_1, test_size=0.2, random_state=seed)

# %%
X_train.reset_index(inplace = True)
X_test.reset_index(inplace = True)
X_valid.reset_index(inplace = True)

# %%
print("Train sample : %.0f "% (X_train.shape[0]))
print("Valid sample : %.0f "% (X_valid.shape[0]))
print("Test sample : %.0f "% (X_test.shape[0]))
# Out:
# Train sample : 757
# Valid sample : 190
# Test sample : 237

# %%
print(y_train.label_l2_enc.value_counts())
print(y_valid.label_l2_enc.value_counts())
print(y_test.label_l2_enc.value_counts())
# Out:
# 0    444
# 1    294
# 2     19
# Name: label_l2_enc, dtype: int64
# 0    119
# 1     68
# 2      3
# Name: label_l2_enc, dtype: int64
# 0    134
# 1    100
# 2      3
# Name: label_l2_enc, dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer

for selected_col in x_column:
    sentences_train = X_train[selected_col].values
    sentences_valid = X_valid[selected_col].values
    sentences_test = X_test[selected_col].values

    vectorizer = CountVectorizer()
    vectorizer.fit(sentences_train)

    X_train = X_train.merge(pd.DataFrame(vectorizer.transform(sentences_train).toarray()),left_index=True, right_index = True)
    X_valid = X_valid.merge(pd.DataFrame(vectorizer.transform(sentences_valid).toarray()),left_index=True, right_index = True)
    X_test  = X_test.merge(pd.DataFrame(vectorizer.transform(sentences_test).toarray()),left_index=True, right_index = True)

# %%
all_col = list(X_train.columns)

# %%
all_col.remove('index')
all_col.remove('material_descr_from_po')
all_col.remove('vendor_desc')
all_col.remove('account_number_desc')
all_col.remove('cost_center_desc')

# %%
from keras.utils import to_categorical

# %% [markdown]
# # LSTM Model

# %%
from keras.models import Sequential
from keras import layers

input_dim = X_train[all_col].shape[1]  # Number of features

model = Sequential()
model.add(layers.Dense(10, input_dim=input_dim, activation='relu'))
model.add(layers.Dense(3, activation='sigmoid'))

# %%
model.compile(loss='categorical_crossentropy', 
               optimizer='adam', 
               metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_11 (Dense)             (None, 10)                7030
# _________________________________________________________________
# dense_12 (Dense)             (None, 3)                 33
# =================================================================
# Total params: 7,063
# Trainable params: 7,063
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train[all_col], to_categorical(y_train),
                     epochs=100,
                     verbose=False,
                     validation_data=(X_valid[all_col], to_categorical(y_valid)),
                     batch_size=50)
# Out:
# WARNING:tensorflow:From C:\Users\aman.khatri91425\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\aman.khatri91425\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
loss, accuracy = model.evaluate(X_train[all_col], to_categorical(y_train), verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(X_valid[all_col], to_categorical(y_valid), verbose=False)
print("Valid Accuracy:  {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(X_test[all_col], to_categorical(y_test), verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
# Out:
# Training Accuracy: 0.9841
# Valid Accuracy:  0.9368
# Testing Accuracy:  0.9072

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'b', label='Training acc')
    plt.plot(x, val_acc, 'r', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

# %%
plot_history(history)

# %% [markdown]
# # Hyperparameter Tuning

# %%
def create_model(learning_rate=0.01, activation='relu'):
  
    # Create an Adam optimizer with the given learning rate
    opt = Adam(lr=learning_rate)
  
    # Create your binary classification model  
    model = Sequential()
    model.add(layers.Dense(10, input_dim=input_dim, activation=activation))
    model.add(layers.Dense(3, activation='sigmoid'))
    # Compile the model
    model.compile(optimizer = opt,
                  loss = 'categorical_crossentropy',
                  metrics=["accuracy"])
    return model

# %%
params = {'activation': ["relu", "tanh"],
          'batch_size': [16, 32, 64], 
          'epochs': [10,20,30,50,80,100,150],
          'learning_rate': [0.01, 0.001, 0.0001]}

# %%
from keras.wrappers.scikit_learn import KerasRegressor
model = KerasRegressor(build_fn = create_model,
                       verbose = 1)

# %%
random_search = RandomizedSearchCV(model,
                                   param_distributions = params, random_state = 10, n_iter = 20,
                                   cv = KFold(3), error_score=0, return_train_score =True)

# %%
print("Randomized search..")
search_time_start = time.time()
random_search.fit(X_train[all_col], to_categorical(y_train))
print("Randomized search time:", time.time() - search_time_start)
# Out:
# Randomized search..
# Epoch 1/150
# 504/504 [==============================] - 1s 1ms/step - loss: 1.0693 - accuracy: 0.5556
# Epoch 2/150
# 504/504 [==============================] - 0s 451us/step - loss: 1.0121 - accuracy: 0.6270
# Epoch 3/150
# 504/504 [==============================] - 0s 342us/step - loss: 0.9632 - accuracy: 0.6508
# Epoch 4/150
# 504/504 [==============================] - 0s 281us/step - loss: 0.9173 - accuracy: 0.6587
# Epoch 5/150
# 504/504 [==============================] - 0s 665us/step - loss: 0.8744 - accuracy: 0.6587
# Epoch 6/150
# 504/504 [==============================] - 0s 433us/step - loss: 0.8337 - accuracy: 0.6587
# Epoch 7/150
# 504/504 [==============================] - 0s 465us/step - loss: 0.7965 - accuracy: 0.6528
# Epoch 8/150
# 504/504 [==============================] - 0s 346us/step - loss: 0.7633 - accuracy: 0.6448
# Epoch 9/150
# 504/504 [==============================] - 0s 532us/step - loss: 0.7326 - accuracy: 0.6429
# Epoch 10/150
# 504/504 [==============================] - 0s 344us/step - loss: 0.7051 - accuracy: 0.6468
# Epoch 11/150
# 504/504 [==============================] - 0s 91us/step - loss: 0.6795 - accuracy: 0.6488
# Epoch 12/150
# 504/504 [==============================] - 0s 83us/step - loss: 0.6565 - accuracy: 0.6488
# Epoch 13/150
# 504/504 [==============================] - 0s 77us/step - loss: 0.6322 - accuracy: 0.6647
# Epoch 14/150
# 504/504 [==============================] - 0s 117us/step - loss: 0.6098 - accuracy: 0.6865
# Epoch 15/150
# 504/504 [==============================] - 0s 79us/step - loss: 0.5870 - accuracy: 0.7063
# Epoch 16/150
# 504/504 [==============================] - 0s 119us/step - loss: 0.5639 - accuracy: 0.7282
# Epoch 17/150
# 504/504 [==============================] - 0s 89us/step - loss: 0.5400 - accuracy: 0.7500
# Epoch 18/150
# 504/504 [==============================] - 0s 131us/step - loss: 0.5153 - accuracy: 0.7679
# Epoch 19/150
# 504/504 [==============================] - 0s 95us/step - loss: 0.4903 - accuracy: 0.7976
# Epoch 20/150
# 504/504 [==============================] - 0s 152us/step - loss: 0.4632 - accuracy: 0.8194
# Epoch 21/150
# 504/504 [==============================] - 0s 119us/step - loss: 0.4362 - accuracy: 0.8552
# Epoch 22/150
# 504/504 [==============================] - 0s 168us/step - loss: 0.4084 - accuracy: 0.8750
# Epoch 23/150
# 504/504 [==============================] - 0s 111us/step - loss: 0.3810 - accuracy: 0.8929
# Epoch 24/150
# 504/504 [==============================] - 0s 103us/step - loss: 0.3550 - accuracy: 0.9107
# Epoch 25/150
# 504/504 [==============================] - 0s 109us/step - loss: 0.3306 - accuracy: 0.9286
# Epoch 26/150
# 504/504 [==============================] - 0s 144us/step - loss: 0.3076 - accuracy: 0.9345
# Epoch 27/150
# 504/504 [==============================] - 0s 81us/step - loss: 0.2876 - accuracy: 0.9405
# Epoch 28/150
# 504/504 [==============================] - 0s 91us/step - loss: 0.2675 - accuracy: 0.9444
# Epoch 29/150
# 504/504 [==============================] - 0s 107us/step - loss: 0.2502 - accuracy: 0.9444
# Epoch 30/150
# 504/504 [==============================] - 0s 162us/step - loss: 0.2342 - accuracy: 0.9524
# Epoch 31/150
# 504/504 [==============================] - 0s 95us/step - loss: 0.2194 - accuracy: 0.9603
# Epoch 32/150
# 504/504 [==============================] - 0s 95us/step - loss: 0.2064 - accuracy: 0.9603
# Epoch 33/150
# 504/504 [==============================] - 0s 99us/step - loss: 0.1952 - accuracy: 0.9683
# Epoch 34/150
# 504/504 [==============================] - 0s 95us/step - loss: 0.1837 - accuracy: 0.9663
# Epoch 35/150
# 504/504 [==============================] - 0s 113us/step - loss: 0.1736 - accuracy: 0.9702
# Epoch 36/150
# 504/504 [==============================] - 0s 113us/step - loss: 0.1646 - accuracy: 0.9702
# Epoch 37/150
# 504/504 [==============================] - 0s 93us/step - loss: 0.1569 - accuracy: 0.9722
# Epoch 38/150
# 504/504 [==============================] - 0s 101us/step - loss: 0.1485 - accuracy: 0.9742
# Epoch 39/150
# 504/504 [==============================] - 0s 83us/step - loss: 0.1418 - accuracy: 0.9722
# Epoch 40/150
# 504/504 [==============================] - 0s 101us/step - loss: 0.1352 - accuracy: 0.9742
# Epoch 41/150
# 504/504 [==============================] - 0s 81us/step - loss: 0.1298 - accuracy: 0.9742
# Epoch 42/150
# 504/504 [==============================] - 0s 91us/step - loss: 0.1243 - accuracy: 0.9762
# Epoch 43/150
# 504/504 [==============================] - 0s 91us/step - loss: 0.1197 - accuracy: 0.9802
# Epoch 44/150
# 504/504 [==============================] - 0s 105us/step - loss: 0.1149 - accuracy: 0.9742
# Epoch 45/150
# 504/504 [==============================] - 0s 111us/step - loss: 0.1108 - accuracy: 0.9782
# Epoch 46/150
# 504/504 [==============================] - 0s 89us/step - loss: 0.1071 - accuracy: 0.9821
# Epoch 47/150
# 504/504 [==============================] - 0s 83us/step - loss: 0.1038 - accuracy: 0.9821
# Epoch 48/150
# 504/504 [==============================] - 0s 121us/step - loss: 0.0998 - accuracy: 0.9841
# Epoch 49/150
# 504/504 [==============================] - 0s 109us/step - loss: 0.0973 - accuracy: 0.9861
# Epoch 50/150
# 504/504 [==============================] - 0s 121us/step - loss: 0.0940 - accuracy: 0.9821
# Epoch 51/150
# 504/504 [==============================] - 0s 97us/step - loss: 0.0913 - accuracy: 0.9841
# Epoch 52/150
# 504/504 [==============================] - 0s 107us/step - loss: 0.0889 - accuracy: 0.9861
# Epoch 53/150
# 504/504 [==============================] - 0s 115us/step - loss: 0.0863 - accuracy: 0.9881
# Epoch 54/150
# 504/504 [==============================] - 0s 127us/step - loss: 0.0839 - accuracy: 0.9841
# Epoch 55/150
# 504/504 [==============================] - 0s 119us/step - loss: 0.0817 - accuracy: 0.9841
# Epoch 56/150
# 504/504 [==============================] - 0s 87us/step - loss: 0.0800 - accuracy: 0.9861
# Epoch 57/150
# 504/504 [==============================] - 0s 113us/step - loss: 0.0778 - accuracy: 0.9881
# Epoch 58/150
# 504/504 [==============================] - 0s 99us/step - loss: 0.0764 - accuracy: 0.9881
# Epoch 59/150
# 504/504 [==============================] - 0s 107us/step - loss: 0.0748 - accuracy: 0.9861
# Epoch 60/150
# 504/504 [==============================] - 0s 408us/step - loss: 0.0729 - accuracy: 0.9881
# Epoch 61/150
# 504/504 [==============================] - 0s 336us/step - loss: 0.0718 - accuracy: 0.9861
# Epoch 62/150
# 504/504 [==============================] - 0s 275us/step - loss: 0.0707 - accuracy: 0.9841
# Epoch 63/150
# 504/504 [==============================] - 0s 402us/step - loss: 0.0685 - accuracy: 0.9861
# Epoch 64/150
# 504/504 [==============================] - 0s 275us/step - loss: 0.0674 - accuracy: 0.9881
# Epoch 65/150
# 504/504 [==============================] - 0s 103us/step - loss: 0.0661 - accuracy: 0.9881
# Epoch 66/150
# 504/504 [==============================] - 0s 65us/step - loss: 0.0647 - accuracy: 0.9881
# Epoch 67/150
# 504/504 [==============================] - 0s 101us/step - loss: 0.0632 - accuracy: 0.9881
# Epoch 68/150
# 504/504 [==============================] - 0s 65us/step - loss: 0.0624 - accuracy: 0.9881
# Epoch 69/150
# 504/504 [==============================] - 0s 267us/step - loss: 0.0615 - accuracy: 0.9901
# Epoch 70/150
# 504/504 [==============================] - 0s 338us/step - loss: 0.0601 - accuracy: 0.9901
# Epoch 71/150
# 504/504 [==============================] - 0s 338us/step - loss: 0.0594 - accuracy: 0.9901
# Epoch 72/150
# 504/504 [==============================] - 0s 148us/step - loss: 0.0583 - accuracy: 0.9901
# Epoch 73/150
# 504/504 [==============================] - 0s 333us/step - loss: 0.0579 - accuracy: 0.9881
# Epoch 74/150
# 504/504 [==============================] - 0s 279us/step - loss: 0.0567 - accuracy: 0.9901
# Epoch 75/150
# 504/504 [==============================] - 0s 283us/step - loss: 0.0558 - accuracy: 0.9901
# Epoch 76/150
# 504/504 [==============================] - 0s 336us/step - loss: 0.0546 - accuracy: 0.9901
# Epoch 77/150
# 504/504 [==============================] - 0s 271us/step - loss: 0.0547 - accuracy: 0.9841
# Epoch 78/150
# 504/504 [==============================] - 0s 408us/step - loss: 0.0531 - accuracy: 0.9881
# Epoch 79/150
# 504/504 [==============================] - 0s 210us/step - loss: 0.0526 - accuracy: 0.9901
# Epoch 80/150
# 504/504 [==============================] - 0s 336us/step - loss: 0.0521 - accuracy: 0.9901
# Epoch 81/150
# 504/504 [==============================] - 0s 277us/step - loss: 0.0513 - accuracy: 0.9901
# Epoch 82/150
# 504/504 [==============================] - 0s 170us/step - loss: 0.0503 - accuracy: 0.9901
# Epoch 83/150
# 504/504 [==============================] - 0s 255us/step - loss: 0.0497 - accuracy: 0.9901
# Epoch 84/150
# 504/504 [==============================] - 0s 336us/step - loss: 0.0493 - accuracy: 0.9901
# Epoch 85/150
# 504/504 [==============================] - 0s 271us/step - loss: 0.0486 - accuracy: 0.9901
# Epoch 86/150
# 504/504 [==============================] - 0s 287us/step - loss: 0.0479 - accuracy: 0.9901
# Epoch 87/150
# 504/504 [==============================] - 0s 325us/step - loss: 0.0476 - accuracy: 0.9901
# Epoch 88/150
# 504/504 [==============================] - 0s 229us/step - loss: 0.0468 - accuracy: 0.9901
# Epoch 89/150
# 504/504 [==============================] - 0s 216us/step - loss: 0.0465 - accuracy: 0.9901
# Epoch 90/150
# 504/504 [==============================] - 0s 404us/step - loss: 0.0465 - accuracy: 0.9881
# Epoch 91/150
# 504/504 [==============================] - 0s 273us/step - loss: 0.0453 - accuracy: 0.9901
# Epoch 92/150
# 504/504 [==============================] - 0s 109us/step - loss: 0.0453 - accuracy: 0.9901
# Epoch 93/150
# 504/504 [==============================] - 0s 73us/step - loss: 0.0448 - accuracy: 0.9901
# Epoch 94/150
# 504/504 [==============================] - 0s 67us/step - loss: 0.0442 - accuracy: 0.9901
# Epoch 95/150
# 504/504 [==============================] - 0s 79us/step - loss: 0.0437 - accuracy: 0.9901
# Epoch 96/150
# 504/504 [==============================] - 0s 85us/step - loss: 0.0430 - accuracy: 0.9881
# Epoch 97/150
# 504/504 [==============================] - 0s 101us/step - loss: 0.0427 - accuracy: 0.9881
# Epoch 98/150
# 504/504 [==============================] - 0s 77us/step - loss: 0.0425 - accuracy: 0.9881
# Epoch 99/150
# 504/504 [==============================] - 0s 89us/step - loss: 0.0420 - accuracy: 0.9881
# Epoch 100/150
# 504/504 [==============================] - 0s 103us/step - loss: 0.0412 - accuracy: 0.9901
# Epoch 101/150
# 504/504 [==============================] - 0s 93us/step - loss: 0.0412 - accuracy: 0.9881
# Epoch 102/150
# 504/504 [==============================] - 0s 83us/step - loss: 0.0410 - accuracy: 0.9881
# Epoch 103/150
# 504/504 [==============================] - 0s 83us/step - loss: 0.0408 - accuracy: 0.9881
# Epoch 104/150
# 504/504 [==============================] - 0s 109us/step - loss: 0.0400 - accuracy: 0.9881
# Epoch 105/150
# 504/504 [==============================] - 0s 77us/step - loss: 0.0396 - accuracy: 0.9901
# Epoch 106/150
# 504/504 [==============================] - 0s 95us/step - loss: 0.0393 - accuracy: 0.9901
# Epoch 107/150
# 504/504 [==============================] - 0s 129us/step - loss: 0.0391 - accuracy: 0.9881
# Epoch 108/150
# 504/504 [==============================] - 0s 192us/step - loss: 0.0390 - accuracy: 0.9901
# Epoch 109/150
# 504/504 [==============================] - 0s 99us/step - loss: 0.0385 - accuracy: 0.9881
# Epoch 110/150
# 504/504 [==============================] - 0s 97us/step - loss: 0.0378 - accuracy: 0.9901
# Epoch 111/150
# 504/504 [==============================] - 0s 109us/step - loss: 0.0378 - accuracy: 0.9881
# Epoch 112/150
# 504/504 [==============================] - 0s 97us/step - loss: 0.0376 - accuracy: 0.9881
# Epoch 113/150
# 504/504 [==============================] - 0s 99us/step - loss: 0.0372 - accuracy: 0.9881
# Epoch 114/150
# 504/504 [==============================] - 0s 89us/step - loss: 0.0371 - accuracy: 0.9881
# Epoch 115/150
# 504/504 [==============================] - 0s 73us/step - loss: 0.0368 - accuracy: 0.9901
# Epoch 116/150
# 504/504 [==============================] - 0s 101us/step - loss: 0.0364 - accuracy: 0.9881
# Epoch 117/150
# 504/504 [==============================] - 0s 63us/step - loss: 0.0361 - accuracy: 0.9901
# Epoch 118/150
# 504/504 [==============================] - 0s 83us/step - loss: 0.0359 - accuracy: 0.9881
# Epoch 119/150
# 504/504 [==============================] - 0s 105us/step - loss: 0.0355 - accuracy: 0.9881
# Epoch 120/150
# 504/504 [==============================] - 0s 77us/step - loss: 0.0354 - accuracy: 0.9901
# Epoch 121/150
# 504/504 [==============================] - 0s 103us/step - loss: 0.0350 - accuracy: 0.9901
# Epoch 122/150
# 504/504 [==============================] - 0s 111us/step - loss: 0.0349 - accuracy: 0.9901
# Epoch 123/150
# 504/504 [==============================] - 0s 87us/step - loss: 0.0346 - accuracy: 0.9881
# Epoch 124/150
# 504/504 [==============================] - 0s 103us/step - loss: 0.0349 - accuracy: 0.9861
# Epoch 125/150
# 504/504 [==============================] - 0s 103us/step - loss: 0.0342 - accuracy: 0.9901
# Epoch 126/150
# 504/504 [==============================] - 0s 198us/step - loss: 0.0338 - accuracy: 0.9901
# Epoch 127/150
# 504/504 [==============================] - 0s 89us/step - loss: 0.0338 - accuracy: 0.9901
# Epoch 128/150
# 504/504 [==============================] - 0s 107us/step - loss: 0.0335 - accuracy: 0.9881
# Epoch 129/150
# 504/504 [==============================] - 0s 95us/step - loss: 0.0333 - accuracy: 0.9901
# Epoch 130/150
# 504/504 [==============================] - 0s 87us/step - loss: 0.0332 - accuracy: 0.9901
# Epoch 131/150
# 504/504 [==============================] - 0s 89us/step - loss: 0.0329 - accuracy: 0.9901
# Epoch 132/150
# 504/504 [==============================] - 0s 109us/step - loss: 0.0330 - accuracy: 0.9901
# Epoch 133/150
# 504/504 [==============================] - 0s 91us/step - loss: 0.0326 - accuracy: 0.9881
# Epoch 134/150
# 504/504 [==============================] - 0s 91us/step - loss: 0.0325 - accuracy: 0.9901
# Epoch 135/150
# 504/504 [==============================] - 0s 73us/step - loss: 0.0328 - accuracy: 0.9881
# Epoch 136/150
# 504/504 [==============================] - 0s 87us/step - loss: 0.0322 - accuracy: 0.9881
# Epoch 137/150
# 504/504 [==============================] - 0s 67us/step - loss: 0.0317 - accuracy: 0.9901
# Epoch 138/150
# 504/504 [==============================] - 0s 109us/step - loss: 0.0315 - accuracy: 0.9901
# Epoch 139/150
# 504/504 [==============================] - 0s 111us/step - loss: 0.0316 - accuracy: 0.9901
# Epoch 140/150
# 504/504 [==============================] - 0s 101us/step - loss: 0.0314 - accuracy: 0.9881
# Epoch 141/150
# 504/504 [==============================] - 0s 109us/step - loss: 0.0316 - accuracy: 0.9861
# Epoch 142/150
# 504/504 [==============================] - 0s 91us/step - loss: 0.0317 - accuracy: 0.9881
# Epoch 143/150
# 504/504 [==============================] - 0s 73us/step - loss: 0.0310 - accuracy: 0.9901
# Epoch 144/150
# 504/504 [==============================] - 0s 97us/step - loss: 0.0307 - accuracy: 0.9901
# Epoch 145/150
# 504/504 [==============================] - 0s 109us/step - loss: 0.0305 - accuracy: 0.9901
# Epoch 146/150
# 504/504 [==============================] - 0s 89us/step - loss: 0.0303 - accuracy: 0.9881
# Epoch 147/150
# 504/504 [==============================] - 0s 117us/step - loss: 0.0303 - accuracy: 0.9901
# Epoch 148/150
# 504/504 [==============================] - 0s 121us/step - loss: 0.0299 - accuracy: 0.9901
# Epoch 149/150
# 504/504 [==============================] - 0s 111us/step - loss: 0.0298 - accuracy: 0.9901
# Epoch 150/150
# 504/504 [==============================] - 0s 93us/step - loss: 0.0298 - accuracy: 0.9881
# 253/253 [==============================] - 0s 382us/step
# 504/504 [==============================] - 0s 69us/step
# Epoch 1/150
# 505/505 [==============================] - 0s 622us/step - loss: 1.0949 - accuracy: 0.3881
# Epoch 2/150
# 505/505 [==============================] - 0s 95us/step - loss: 1.0648 - accuracy: 0.6356
# Epoch 3/150
# 505/505 [==============================] - 0s 93us/step - loss: 1.0407 - accuracy: 0.6931
# Epoch 4/150
# 505/505 [==============================] - 0s 99us/step - loss: 1.0159 - accuracy: 0.7129
# Epoch 5/150
# 505/505 [==============================] - 0s 77us/step - loss: 0.9892 - accuracy: 0.7426
# Epoch 6/150
# 505/505 [==============================] - 0s 95us/step - loss: 0.9608 - accuracy: 0.7822
# Epoch 7/150
# 505/505 [==============================] - 0s 73us/step - loss: 0.9298 - accuracy: 0.8178
# Epoch 8/150
# 505/505 [==============================] - 0s 79us/step - loss: 0.8963 - accuracy: 0.8356
# Epoch 9/150
# 505/505 [==============================] - 0s 87us/step - loss: 0.8584 - accuracy: 0.8535
# Epoch 10/150
# 505/505 [==============================] - 0s 93us/step - loss: 0.8182 - accuracy: 0.8733
# Epoch 11/150
# 505/505 [==============================] - 0s 71us/step - loss: 0.7752 - accuracy: 0.8752
# Epoch 12/150
# 505/505 [==============================] - 0s 87us/step - loss: 0.7321 - accuracy: 0.8812
# Epoch 13/150
# 505/505 [==============================] - 0s 77us/step - loss: 0.6881 - accuracy: 0.8851
# Epoch 14/150
# 505/505 [==============================] - 0s 81us/step - loss: 0.6448 - accuracy: 0.8812
# Epoch 15/150
# 505/505 [==============================] - 0s 219us/step - loss: 0.6010 - accuracy: 0.8911
# Epoch 16/150
# 505/505 [==============================] - 0s 156us/step - loss: 0.5595 - accuracy: 0.9030
# Epoch 17/150
# 505/505 [==============================] - 0s 103us/step - loss: 0.5193 - accuracy: 0.9050
# Epoch 18/150
# 505/505 [==============================] - 0s 77us/step - loss: 0.4821 - accuracy: 0.9010
# Epoch 19/150
# 505/505 [==============================] - 0s 101us/step - loss: 0.4472 - accuracy: 0.9168
# Epoch 20/150
# 505/505 [==============================] - 0s 111us/step - loss: 0.4140 - accuracy: 0.9188
# Epoch 21/150
# 505/505 [==============================] - 0s 89us/step - loss: 0.3847 - accuracy: 0.9188
# Epoch 22/150
# 505/505 [==============================] - 0s 77us/step - loss: 0.3576 - accuracy: 0.9208
# Epoch 23/150
# 505/505 [==============================] - 0s 111us/step - loss: 0.3338 - accuracy: 0.9267
# Epoch 24/150
# 505/505 [==============================] - 0s 85us/step - loss: 0.3119 - accuracy: 0.9287
# Epoch 25/150
# 505/505 [==============================] - 0s 79us/step - loss: 0.2925 - accuracy: 0.9347
# Epoch 26/150
# 505/505 [==============================] - 0s 115us/step - loss: 0.2751 - accuracy: 0.9347
# Epoch 27/150
# 505/505 [==============================] - 0s 93us/step - loss: 0.2595 - accuracy: 0.9386
# Epoch 28/150
# 505/505 [==============================] - 0s 83us/step - loss: 0.2457 - accuracy: 0.9446
# Epoch 29/150
# 505/505 [==============================] - 0s 99us/step - loss: 0.2335 - accuracy: 0.9446
# Epoch 30/150
# 505/505 [==============================] - 0s 85us/step - loss: 0.2216 - accuracy: 0.9485
# Epoch 31/150
# 505/505 [==============================] - 0s 75us/step - loss: 0.2115 - accuracy: 0.9485
# Epoch 32/150
# 505/505 [==============================] - 0s 99us/step - loss: 0.2019 - accuracy: 0.9505
# Epoch 33/150
# 505/505 [==============================] - 0s 93us/step - loss: 0.1933 - accuracy: 0.9525
# Epoch 34/150
# 505/505 [==============================] - 0s 190us/step - loss: 0.1850 - accuracy: 0.9525
# Epoch 35/150
# 505/505 [==============================] - 0s 275us/step - loss: 0.1778 - accuracy: 0.9564
# Epoch 36/150
# 505/505 [==============================] - 0s 401us/step - loss: 0.1718 - accuracy: 0.9584
# Epoch 37/150
# 505/505 [==============================] - 0s 213us/step - loss: 0.1641 - accuracy: 0.9663
# Epoch 38/150
# 505/505 [==============================] - 0s 276us/step - loss: 0.1594 - accuracy: 0.9604
# Epoch 39/150
# 505/505 [==============================] - 0s 271us/step - loss: 0.1535 - accuracy: 0.9683
# Epoch 40/150
# 505/505 [==============================] - 0s 348us/step - loss: 0.1474 - accuracy: 0.9683
# Epoch 41/150
# 505/505 [==============================] - 0s 93us/step - loss: 0.1423 - accuracy: 0.9683
# Epoch 42/150
# 505/505 [==============================] - 0s 93us/step - loss: 0.1375 - accuracy: 0.9703
# Epoch 43/150
# 505/505 [==============================] - 0s 105us/step - loss: 0.1332 - accuracy: 0.9703
# Epoch 44/150
# 505/505 [==============================] - 0s 61us/step - loss: 0.1287 - accuracy: 0.9703
# Epoch 45/150
# 505/505 [==============================] - 0s 192us/step - loss: 0.1249 - accuracy: 0.9703
# Epoch 46/150
# 505/505 [==============================] - 0s 209us/step - loss: 0.1211 - accuracy: 0.9703
# Epoch 47/150
# 505/505 [==============================] - 0s 239us/step - loss: 0.1174 - accuracy: 0.9703
# Epoch 48/150
# 505/505 [==============================] - 0s 312us/step - loss: 0.1139 - accuracy: 0.9703
# Epoch 49/150
# 505/505 [==============================] - 0s 474us/step - loss: 0.1112 - accuracy: 0.9723
# Epoch 50/150
# 505/505 [==============================] - 0s 409us/step - loss: 0.1078 - accuracy: 0.9723
# Epoch 51/150
# 505/505 [==============================] - 0s 399us/step - loss: 0.1043 - accuracy: 0.9723
# Epoch 52/150
# 505/505 [==============================] - 0s 346us/step - loss: 0.1018 - accuracy: 0.9743
# Epoch 53/150
# 505/505 [==============================] - 0s 399us/step - loss: 0.0992 - accuracy: 0.9762
# Epoch 54/150
# 505/505 [==============================] - 0s 405us/step - loss: 0.0962 - accuracy: 0.9762
# Epoch 55/150
# 505/505 [==============================] - 0s 271us/step - loss: 0.0936 - accuracy: 0.9782
# Epoch 56/150
# 505/505 [==============================] - 0s 355us/step - loss: 0.0914 - accuracy: 0.9762
# Epoch 57/150
# 505/505 [==============================] - 0s 340us/step - loss: 0.0887 - accuracy: 0.9762
# Epoch 58/150
# 505/505 [==============================] - 0s 290us/step - loss: 0.0866 - accuracy: 0.9822
# Epoch 59/150
# 505/505 [==============================] - 0s 359us/step - loss: 0.0844 - accuracy: 0.9802
# Epoch 60/150
# 505/505 [==============================] - 0s 502us/step - loss: 0.0822 - accuracy: 0.9822
# Epoch 61/150
# 505/505 [==============================] - 0s 547us/step - loss: 0.0803 - accuracy: 0.9842
# Epoch 62/150
# 505/505 [==============================] - 0s 296us/step - loss: 0.0780 - accuracy: 0.9842
# Epoch 63/150
# 505/505 [==============================] - 0s 282us/step - loss: 0.0762 - accuracy: 0.9842
# Epoch 64/150
# 505/505 [==============================] - 0s 399us/step - loss: 0.0744 - accuracy: 0.9861
# Epoch 65/150
# 505/505 [==============================] - 0s 336us/step - loss: 0.0726 - accuracy: 0.9861
# Epoch 66/150
# 505/505 [==============================] - 0s 355us/step - loss: 0.0707 - accuracy: 0.9861
# Epoch 67/150
# 505/505 [==============================] - 0s 172us/step - loss: 0.0689 - accuracy: 0.9881
# Epoch 68/150
# 505/505 [==============================] - 0s 101us/step - loss: 0.0672 - accuracy: 0.9881
# Epoch 69/150
# 505/505 [==============================] - 0s 81us/step - loss: 0.0653 - accuracy: 0.9881
# Epoch 70/150
# 505/505 [==============================] - 0s 77us/step - loss: 0.0638 - accuracy: 0.9901
# Epoch 71/150
# 505/505 [==============================] - 0s 97us/step - loss: 0.0621 - accuracy: 0.9901
# Epoch 72/150
# 505/505 [==============================] - 0s 95us/step - loss: 0.0607 - accuracy: 0.9921
# Epoch 73/150
# 505/505 [==============================] - 0s 164us/step - loss: 0.0592 - accuracy: 0.9921
# Epoch 74/150
# 505/505 [==============================] - 0s 148us/step - loss: 0.0577 - accuracy: 0.9921
# Epoch 75/150
# 505/505 [==============================] - 0s 93us/step - loss: 0.0565 - accuracy: 0.9901
# Epoch 76/150
# 505/505 [==============================] - 0s 115us/step - loss: 0.0550 - accuracy: 0.9921
# Epoch 77/150
# 505/505 [==============================] - 0s 117us/step - loss: 0.0536 - accuracy: 0.9921
# Epoch 78/150
# 505/505 [==============================] - 0s 89us/step - loss: 0.0524 - accuracy: 0.9921
# Epoch 79/150
# 505/505 [==============================] - 0s 87us/step - loss: 0.0513 - accuracy: 0.9921
# Epoch 80/150
# 505/505 [==============================] - 0s 150us/step - loss: 0.0503 - accuracy: 0.9921
# Epoch 81/150
# 505/505 [==============================] - 0s 101us/step - loss: 0.0491 - accuracy: 0.9921
# Epoch 82/150
# 505/505 [==============================] - 0s 119us/step - loss: 0.0484 - accuracy: 0.9921
# Epoch 83/150
# 505/505 [==============================] - 0s 67us/step - loss: 0.0470 - accuracy: 0.9921
# Epoch 84/150
# 505/505 [==============================] - 0s 83us/step - loss: 0.0461 - accuracy: 0.9921
# Epoch 85/150
# 505/505 [==============================] - 0s 79us/step - loss: 0.0454 - accuracy: 0.9921
# Epoch 86/150
# 505/505 [==============================] - 0s 115us/step - loss: 0.0441 - accuracy: 0.9921
# Epoch 87/150
# 505/505 [==============================] - 0s 83us/step - loss: 0.0434 - accuracy: 0.9921
# Epoch 88/150
# 505/505 [==============================] - 0s 91us/step - loss: 0.0427 - accuracy: 0.9921
# Epoch 89/150
# 505/505 [==============================] - 0s 89us/step - loss: 0.0421 - accuracy: 0.9921
# Epoch 90/150
# 505/505 [==============================] - 0s 87us/step - loss: 0.0412 - accuracy: 0.9921
# Epoch 91/150
# 505/505 [==============================] - 0s 101us/step - loss: 0.0405 - accuracy: 0.9901
# Epoch 92/150
# 505/505 [==============================] - 0s 73us/step - loss: 0.0398 - accuracy: 0.9921
# Epoch 93/150
# 505/505 [==============================] - 0s 85us/step - loss: 0.0389 - accuracy: 0.9921
# Epoch 94/150
# 505/505 [==============================] - 0s 91us/step - loss: 0.0385 - accuracy: 0.9921
# Epoch 95/150
# 505/505 [==============================] - 0s 83us/step - loss: 0.0377 - accuracy: 0.9921
# Epoch 96/150
# 505/505 [==============================] - 0s 89us/step - loss: 0.0370 - accuracy: 0.9921
# Epoch 97/150
# 505/505 [==============================] - 0s 117us/step - loss: 0.0370 - accuracy: 0.9901
# Epoch 98/150
# 505/505 [==============================] - 0s 111us/step - loss: 0.0358 - accuracy: 0.9901
# Epoch 99/150
# 505/505 [==============================] - 0s 140us/step - loss: 0.0352 - accuracy: 0.9921
# Epoch 100/150
# 505/505 [==============================] - 0s 75us/step - loss: 0.0347 - accuracy: 0.9921
# Epoch 101/150
# 505/505 [==============================] - 0s 117us/step - loss: 0.0343 - accuracy: 0.9901
# Epoch 102/150
# 505/505 [==============================] - 0s 79us/step - loss: 0.0336 - accuracy: 0.9901
# Epoch 103/150
# 505/505 [==============================] - 0s 107us/step - loss: 0.0332 - accuracy: 0.9921
# Epoch 104/150
# 505/505 [==============================] - 0s 89us/step - loss: 0.0328 - accuracy: 0.9921
# Epoch 105/150
# 505/505 [==============================] - 0s 91us/step - loss: 0.0322 - accuracy: 0.9921
# Epoch 106/150
# 505/505 [==============================] - 0s 67us/step - loss: 0.0319 - accuracy: 0.9921
# Epoch 107/150
# 505/505 [==============================] - 0s 128us/step - loss: 0.0315 - accuracy: 0.9921
# Epoch 108/150
# 505/505 [==============================] - 0s 164us/step - loss: 0.0312 - accuracy: 0.9921
# Epoch 109/150
# 505/505 [==============================] - 0s 144us/step - loss: 0.0306 - accuracy: 0.9921
# Epoch 110/150
# 505/505 [==============================] - 0s 107us/step - loss: 0.0301 - accuracy: 0.9921
# Epoch 111/150
# 505/505 [==============================] - 0s 73us/step - loss: 0.0302 - accuracy: 0.9921
# Epoch 112/150
# 505/505 [==============================] - 0s 69us/step - loss: 0.0294 - accuracy: 0.9941
# Epoch 113/150
# 505/505 [==============================] - ETA: 0s - loss: 0.0170 - accuracy: 1.00 - 0s 97us/step - loss: 0.0290 - accuracy: 0.9921
# Epoch 114/150
# 505/505 [==============================] - 0s 81us/step - loss: 0.0286 - accuracy: 0.9941
# Epoch 115/150
# 505/505 [==============================] - 0s 79us/step - loss: 0.0286 - accuracy: 0.9941
# Epoch 116/150
# 505/505 [==============================] - 0s 77us/step - loss: 0.0279 - accuracy: 0.9941
# Epoch 117/150
# 505/505 [==============================] - 0s 85us/step - loss: 0.0278 - accuracy: 0.9941
# Epoch 118/150
# 505/505 [==============================] - 0s 87us/step - loss: 0.0274 - accuracy: 0.9941
# Epoch 119/150
# 505/505 [==============================] - 0s 150us/step - loss: 0.0271 - accuracy: 0.9921
# Epoch 120/150
# 505/505 [==============================] - 0s 148us/step - loss: 0.0271 - accuracy: 0.9941
# Epoch 121/150
# 505/505 [==============================] - 0s 91us/step - loss: 0.0264 - accuracy: 0.9941
# Epoch 122/150
# 505/505 [==============================] - 0s 109us/step - loss: 0.0261 - accuracy: 0.9941
# Epoch 123/150
# 505/505 [==============================] - 0s 138us/step - loss: 0.0259 - accuracy: 0.9941
# Epoch 124/150
# 505/505 [==============================] - 0s 99us/step - loss: 0.0258 - accuracy: 0.9921
# Epoch 125/150
# 505/505 [==============================] - 0s 124us/step - loss: 0.0255 - accuracy: 0.9941
# Epoch 126/150
# 505/505 [==============================] - 0s 111us/step - loss: 0.0253 - accuracy: 0.9921
# Epoch 127/150
# 505/505 [==============================] - 0s 97us/step - loss: 0.0250 - accuracy: 0.9921
# Epoch 128/150
# 505/505 [==============================] - 0s 113us/step - loss: 0.0246 - accuracy: 0.9941
# Epoch 129/150
# 505/505 [==============================] - 0s 85us/step - loss: 0.0245 - accuracy: 0.9941
# Epoch 130/150
# 505/505 [==============================] - 0s 95us/step - loss: 0.0241 - accuracy: 0.9941
# Epoch 131/150
# 505/505 [==============================] - 0s 79us/step - loss: 0.0239 - accuracy: 0.9941
# Epoch 132/150
# 505/505 [==============================] - 0s 142us/step - loss: 0.0237 - accuracy: 0.9921
# Epoch 133/150
# 505/505 [==============================] - 0s 213us/step - loss: 0.0235 - accuracy: 0.9921
# Epoch 134/150
# 505/505 [==============================] - 0s 111us/step - loss: 0.0232 - accuracy: 0.9941
# Epoch 135/150
# 505/505 [==============================] - 0s 150us/step - loss: 0.0229 - accuracy: 0.9941
# Epoch 136/150
# 505/505 [==============================] - 0s 132us/step - loss: 0.0228 - accuracy: 0.9941
# Epoch 137/150
# 505/505 [==============================] - 0s 122us/step - loss: 0.0227 - accuracy: 0.9941
# Epoch 138/150
# 505/505 [==============================] - 0s 101us/step - loss: 0.0224 - accuracy: 0.9941
# Epoch 139/150
# 505/505 [==============================] - 0s 259us/step - loss: 0.0222 - accuracy: 0.9941
# Epoch 140/150
# 505/505 [==============================] - 0s 223us/step - loss: 0.0221 - accuracy: 0.9941
# Epoch 141/150
# 505/505 [==============================] - 0s 182us/step - loss: 0.0218 - accuracy: 0.9921
# Epoch 142/150
# 505/505 [==============================] - 0s 136us/step - loss: 0.0217 - accuracy: 0.9941
# Epoch 143/150
# 505/505 [==============================] - 0s 160us/step - loss: 0.0216 - accuracy: 0.9921
# Epoch 144/150
# 505/505 [==============================] - 0s 130us/step - loss: 0.0214 - accuracy: 0.9941
# Epoch 145/150
# 505/505 [==============================] - 0s 152us/step - loss: 0.0210 - accuracy: 0.9941
# Epoch 146/150
# 505/505 [==============================] - 0s 324us/step - loss: 0.0209 - accuracy: 0.9960
# Epoch 147/150
# 505/505 [==============================] - 0s 245us/step - loss: 0.0208 - accuracy: 0.9941
# Epoch 148/150
# 505/505 [==============================] - 0s 120us/step - loss: 0.0207 - accuracy: 0.9941
# Epoch 149/150
# 505/505 [==============================] - 0s 144us/step - loss: 0.0204 - accuracy: 0.9941
# Epoch 150/150
# 505/505 [==============================] - 0s 111us/step - loss: 0.0204 - accuracy: 0.9941
# 252/252 [==============================] - 0s 459us/step
# 505/505 [==============================] - 0s 73us/step
# Epoch 1/150
# 505/505 [==============================] - 0s 794us/step - loss: 1.0446 - accuracy: 0.5762
# Epoch 2/150
# 505/505 [==============================] - 0s 124us/step - loss: 0.9836 - accuracy: 0.6099
# Epoch 3/150
# 505/505 [==============================] - 0s 162us/step - loss: 0.9198 - accuracy: 0.6139
# Epoch 4/150
# 505/505 [==============================] - 0s 120us/step - loss: 0.8596 - accuracy: 0.6040
# Epoch 5/150
# 505/505 [==============================] - 0s 97us/step - loss: 0.8081 - accuracy: 0.5901
# Epoch 6/150
# 505/505 [==============================] - 0s 93us/step - loss: 0.7681 - accuracy: 0.5901
# Epoch 7/150
# 505/505 [==============================] - 0s 97us/step - loss: 0.7365 - accuracy: 0.5921
# Epoch 8/150
# 505/505 [==============================] - 0s 115us/step - loss: 0.7113 - accuracy: 0.6000
# Epoch 9/150
# 505/505 [==============================] - 0s 409us/step - loss: 0.6909 - accuracy: 0.6059
# Epoch 10/150
# 505/505 [==============================] - 0s 425us/step - loss: 0.6720 - accuracy: 0.6119
# Epoch 11/150
# 505/505 [==============================] - 0s 280us/step - loss: 0.6547 - accuracy: 0.6198
# Epoch 12/150
# 505/505 [==============================] - 0s 409us/step - loss: 0.6380 - accuracy: 0.6257
# Epoch 13/150
# 505/505 [==============================] - 0s 349us/step - loss: 0.6208 - accuracy: 0.6356
# Epoch 14/150
# 505/505 [==============================] - 0s 97us/step - loss: 0.6031 - accuracy: 0.6455
# Epoch 15/150
# 505/505 [==============================] - 0s 79us/step - loss: 0.5849 - accuracy: 0.6673
# Epoch 16/150
# 505/505 [==============================] - 0s 156us/step - loss: 0.5664 - accuracy: 0.6911
# Epoch 17/150
# 505/505 [==============================] - 0s 107us/step - loss: 0.5472 - accuracy: 0.7327
# Epoch 18/150
# 505/505 [==============================] - 0s 85us/step - loss: 0.5284 - accuracy: 0.7564
# Epoch 19/150
# 505/505 [==============================] - 0s 109us/step - loss: 0.5094 - accuracy: 0.7703
# Epoch 20/150
# 505/505 [==============================] - 0s 95us/step - loss: 0.4905 - accuracy: 0.7901
# Epoch 21/150
# 505/505 [==============================] - 0s 128us/step - loss: 0.4721 - accuracy: 0.8079
# Epoch 22/150
# 505/505 [==============================] - 0s 421us/step - loss: 0.4543 - accuracy: 0.8238
# Epoch 23/150
# 505/505 [==============================] - 0s 363us/step - loss: 0.4356 - accuracy: 0.8297
# Epoch 24/150
# 505/505 [==============================] - 0s 547us/step - loss: 0.4183 - accuracy: 0.8376
# Epoch 25/150
# 505/505 [==============================] - 0s 478us/step - loss: 0.4007 - accuracy: 0.8495
# Epoch 26/150
# 505/505 [==============================] - 0s 417us/step - loss: 0.3824 - accuracy: 0.8653
# Epoch 27/150
# 505/505 [==============================] - 0s 466us/step - loss: 0.3650 - accuracy: 0.8752
# Epoch 28/150
# 505/505 [==============================] - 0s 354us/step - loss: 0.3476 - accuracy: 0.8911
# Epoch 29/150
# 505/505 [==============================] - 0s 409us/step - loss: 0.3306 - accuracy: 0.9010
# Epoch 30/150
# 505/505 [==============================] - 0s 209us/step - loss: 0.3135 - accuracy: 0.9069
# Epoch 31/150
# 505/505 [==============================] - 0s 302us/step - loss: 0.2970 - accuracy: 0.9188
# Epoch 32/150
# 505/505 [==============================] - 0s 332us/step - loss: 0.2814 - accuracy: 0.9267
# Epoch 33/150
# 505/505 [==============================] - 0s 344us/step - loss: 0.2657 - accuracy: 0.9307
# Epoch 34/150
# 505/505 [==============================] - 0s 225us/step - loss: 0.2508 - accuracy: 0.9307
# Epoch 35/150
# 505/505 [==============================] - 0s 464us/step - loss: 0.2375 - accuracy: 0.9366
# Epoch 36/150
# 505/505 [==============================] - 0s 355us/step - loss: 0.2246 - accuracy: 0.9366
# Epoch 37/150
# 505/505 [==============================] - 0s 326us/step - loss: 0.2126 - accuracy: 0.9406
# Epoch 38/150
# 505/505 [==============================] - 0s 275us/step - loss: 0.2021 - accuracy: 0.9485
# Epoch 39/150
# 505/505 [==============================] - 0s 547us/step - loss: 0.1924 - accuracy: 0.9545
# Epoch 40/150
# 505/505 [==============================] - 0s 492us/step - loss: 0.1839 - accuracy: 0.9545
# Epoch 41/150
# 505/505 [==============================] - 0s 239us/step - loss: 0.1749 - accuracy: 0.9545
# Epoch 42/150
# 505/505 [==============================] - 0s 118us/step - loss: 0.1672 - accuracy: 0.9545
# Epoch 43/150
# 505/505 [==============================] - 0s 97us/step - loss: 0.1605 - accuracy: 0.9584
# Epoch 44/150
# 505/505 [==============================] - 0s 89us/step - loss: 0.1541 - accuracy: 0.9624
# Epoch 45/150
# 505/505 [==============================] - 0s 121us/step - loss: 0.1481 - accuracy: 0.9683
# Epoch 46/150
# 505/505 [==============================] - 0s 95us/step - loss: 0.1431 - accuracy: 0.9703
# Epoch 47/150
# 505/505 [==============================] - 0s 111us/step - loss: 0.1388 - accuracy: 0.9703
# Epoch 48/150
# 505/505 [==============================] - 0s 148us/step - loss: 0.1335 - accuracy: 0.9703
# Epoch 49/150
# 505/505 [==============================] - 0s 93us/step - loss: 0.1295 - accuracy: 0.9743
# Epoch 50/150
# 505/505 [==============================] - 0s 144us/step - loss: 0.1254 - accuracy: 0.9743
# Epoch 51/150
# 505/505 [==============================] - 0s 93us/step - loss: 0.1215 - accuracy: 0.9743
# Epoch 52/150
# 505/505 [==============================] - 0s 138us/step - loss: 0.1184 - accuracy: 0.9743
# Epoch 53/150
# 505/505 [==============================] - 0s 95us/step - loss: 0.1148 - accuracy: 0.9743
# Epoch 54/150
# 505/505 [==============================] - 0s 117us/step - loss: 0.1120 - accuracy: 0.9743
# Epoch 55/150
# 505/505 [==============================] - 0s 81us/step - loss: 0.1089 - accuracy: 0.9762
# Epoch 56/150
# 505/505 [==============================] - 0s 113us/step - loss: 0.1060 - accuracy: 0.9762
# Epoch 57/150
# 505/505 [==============================] - 0s 182us/step - loss: 0.1040 - accuracy: 0.9762
# Epoch 58/150
# 505/505 [==============================] - 0s 134us/step - loss: 0.1011 - accuracy: 0.9782
# Epoch 59/150
# 505/505 [==============================] - 0s 126us/step - loss: 0.0987 - accuracy: 0.9782
# Epoch 60/150
# 505/505 [==============================] - 0s 107us/step - loss: 0.0964 - accuracy: 0.9782
# Epoch 61/150
# 505/505 [==============================] - 0s 99us/step - loss: 0.0945 - accuracy: 0.9782
# Epoch 62/150
# 505/505 [==============================] - 0s 162us/step - loss: 0.0923 - accuracy: 0.9762
# Epoch 63/150
# 505/505 [==============================] - 0s 162us/step - loss: 0.0904 - accuracy: 0.9782
# Epoch 64/150
# 505/505 [==============================] - 0s 132us/step - loss: 0.0885 - accuracy: 0.9802
# Epoch 65/150
# 505/505 [==============================] - 0s 162us/step - loss: 0.0870 - accuracy: 0.9782
# Epoch 66/150
# 505/505 [==============================] - 0s 93us/step - loss: 0.0855 - accuracy: 0.9782
# Epoch 67/150
# 505/505 [==============================] - 0s 170us/step - loss: 0.0844 - accuracy: 0.9802
# Epoch 68/150
# 505/505 [==============================] - 0s 109us/step - loss: 0.0824 - accuracy: 0.9802
# Epoch 69/150
# 505/505 [==============================] - 0s 118us/step - loss: 0.0813 - accuracy: 0.9782
# Epoch 70/150
# 505/505 [==============================] - 0s 130us/step - loss: 0.0804 - accuracy: 0.9782
# Epoch 71/150
# 505/505 [==============================] - 0s 221us/step - loss: 0.0781 - accuracy: 0.9802
# Epoch 72/150
# 505/505 [==============================] - 0s 113us/step - loss: 0.0768 - accuracy: 0.9782
# Epoch 73/150
# 505/505 [==============================] - 0s 128us/step - loss: 0.0754 - accuracy: 0.9802
# Epoch 74/150
# 505/505 [==============================] - 0s 91us/step - loss: 0.0747 - accuracy: 0.9762
# Epoch 75/150
# 505/505 [==============================] - 0s 130us/step - loss: 0.0730 - accuracy: 0.9802
# Epoch 76/150
# 505/505 [==============================] - 0s 140us/step - loss: 0.0720 - accuracy: 0.9802
# Epoch 77/150
# 505/505 [==============================] - 0s 130us/step - loss: 0.0708 - accuracy: 0.9802
# Epoch 78/150
# 505/505 [==============================] - 0s 128us/step - loss: 0.0699 - accuracy: 0.9802
# Epoch 79/150
# 505/505 [==============================] - 0s 128us/step - loss: 0.0688 - accuracy: 0.9802
# Epoch 80/150
# 505/505 [==============================] - 0s 87us/step - loss: 0.0684 - accuracy: 0.9762
# Epoch 81/150
# 505/505 [==============================] - 0s 119us/step - loss: 0.0673 - accuracy: 0.9802
# Epoch 82/150
# 505/505 [==============================] - 0s 117us/step - loss: 0.0661 - accuracy: 0.9802
# Epoch 83/150
# 505/505 [==============================] - 0s 97us/step - loss: 0.0661 - accuracy: 0.9762
# Epoch 84/150
# 505/505 [==============================] - 0s 146us/step - loss: 0.0647 - accuracy: 0.9782
# Epoch 85/150
# 505/505 [==============================] - 0s 128us/step - loss: 0.0636 - accuracy: 0.9802
# Epoch 86/150
# 505/505 [==============================] - 0s 85us/step - loss: 0.0629 - accuracy: 0.9802
# Epoch 87/150
# 505/505 [==============================] - 0s 113us/step - loss: 0.0622 - accuracy: 0.9802
# Epoch 88/150
# 505/505 [==============================] - 0s 117us/step - loss: 0.0612 - accuracy: 0.9802
# Epoch 89/150
# 505/505 [==============================] - 0s 107us/step - loss: 0.0606 - accuracy: 0.9822
# Epoch 90/150
# 505/505 [==============================] - 0s 126us/step - loss: 0.0601 - accuracy: 0.9802
# Epoch 91/150
# 505/505 [==============================] - 0s 101us/step - loss: 0.0592 - accuracy: 0.9802
# Epoch 92/150
# 505/505 [==============================] - 0s 95us/step - loss: 0.0584 - accuracy: 0.9822
# Epoch 93/150
# 505/505 [==============================] - 0s 83us/step - loss: 0.0582 - accuracy: 0.9802
# Epoch 94/150
# 505/505 [==============================] - 0s 101us/step - loss: 0.0574 - accuracy: 0.9822
# Epoch 95/150
# 505/505 [==============================] - 0s 93us/step - loss: 0.0568 - accuracy: 0.9802
# Epoch 96/150
# 505/505 [==============================] - 0s 124us/step - loss: 0.0568 - accuracy: 0.9762
# Epoch 97/150
# 505/505 [==============================] - 0s 97us/step - loss: 0.0551 - accuracy: 0.9822
# Epoch 98/150
# 505/505 [==============================] - 0s 164us/step - loss: 0.0552 - accuracy: 0.9822
# Epoch 99/150
# 505/505 [==============================] - 0s 109us/step - loss: 0.0543 - accuracy: 0.9822
# Epoch 100/150
# 505/505 [==============================] - 0s 130us/step - loss: 0.0538 - accuracy: 0.9822
# Epoch 101/150
# 505/505 [==============================] - 0s 97us/step - loss: 0.0535 - accuracy: 0.9822
# Epoch 102/150
# 505/505 [==============================] - 0s 77us/step - loss: 0.0529 - accuracy: 0.9822
# Epoch 103/150
# 505/505 [==============================] - 0s 152us/step - loss: 0.0526 - accuracy: 0.9842
# Epoch 104/150
# 505/505 [==============================] - 0s 121us/step - loss: 0.0522 - accuracy: 0.9802
# Epoch 105/150
# 505/505 [==============================] - 0s 103us/step - loss: 0.0516 - accuracy: 0.9822
# Epoch 106/150
# 505/505 [==============================] - 0s 77us/step - loss: 0.0516 - accuracy: 0.9802
# Epoch 107/150
# 505/505 [==============================] - 0s 87us/step - loss: 0.0507 - accuracy: 0.9802
# Epoch 108/150
# 505/505 [==============================] - 0s 85us/step - loss: 0.0501 - accuracy: 0.9782
# Epoch 109/150
# 505/505 [==============================] - 0s 109us/step - loss: 0.0503 - accuracy: 0.9802
# Epoch 110/150
# 505/505 [==============================] - 0s 79us/step - loss: 0.0497 - accuracy: 0.9842
# Epoch 111/150
# 505/505 [==============================] - 0s 115us/step - loss: 0.0493 - accuracy: 0.9822
# Epoch 112/150
# 505/505 [==============================] - 0s 69us/step - loss: 0.0484 - accuracy: 0.9842
# Epoch 113/150
# 505/505 [==============================] - 0s 99us/step - loss: 0.0481 - accuracy: 0.9842
# Epoch 114/150
# 505/505 [==============================] - 0s 77us/step - loss: 0.0477 - accuracy: 0.9842
# Epoch 115/150
# 505/505 [==============================] - 0s 85us/step - loss: 0.0474 - accuracy: 0.9802
# Epoch 116/150
# 505/505 [==============================] - 0s 122us/step - loss: 0.0473 - accuracy: 0.9822
# Epoch 117/150
# 505/505 [==============================] - 0s 103us/step - loss: 0.0466 - accuracy: 0.9822
# Epoch 118/150
# 505/505 [==============================] - 0s 124us/step - loss: 0.0472 - accuracy: 0.9822
# Epoch 119/150
# 505/505 [==============================] - 0s 93us/step - loss: 0.0467 - accuracy: 0.9762
# Epoch 120/150
# 505/505 [==============================] - 0s 99us/step - loss: 0.0458 - accuracy: 0.9822
# Epoch 121/150
# 505/505 [==============================] - 0s 97us/step - loss: 0.0455 - accuracy: 0.9861
# Epoch 122/150
# 505/505 [==============================] - 0s 89us/step - loss: 0.0449 - accuracy: 0.9842
# Epoch 123/150
# 505/505 [==============================] - 0s 77us/step - loss: 0.0449 - accuracy: 0.9822
# Epoch 124/150
# 505/505 [==============================] - 0s 89us/step - loss: 0.0445 - accuracy: 0.9822
# Epoch 125/150
# 505/505 [==============================] - 0s 75us/step - loss: 0.0445 - accuracy: 0.9842
# Epoch 126/150
# 505/505 [==============================] - 0s 93us/step - loss: 0.0438 - accuracy: 0.9842
# Epoch 127/150
# 505/505 [==============================] - 0s 101us/step - loss: 0.0443 - accuracy: 0.9782
# Epoch 128/150
# 505/505 [==============================] - 0s 124us/step - loss: 0.0432 - accuracy: 0.9842
# Epoch 129/150
# 505/505 [==============================] - 0s 105us/step - loss: 0.0435 - accuracy: 0.9842
# Epoch 130/150
# 505/505 [==============================] - 0s 65us/step - loss: 0.0426 - accuracy: 0.9842
# Epoch 131/150
# 505/505 [==============================] - 0s 170us/step - loss: 0.0427 - accuracy: 0.9822
# Epoch 132/150
# 505/505 [==============================] - 0s 124us/step - loss: 0.0428 - accuracy: 0.9782
# Epoch 133/150
# 505/505 [==============================] - 0s 103us/step - loss: 0.0419 - accuracy: 0.9842
# Epoch 134/150
# 505/505 [==============================] - 0s 89us/step - loss: 0.0418 - accuracy: 0.9842
# Epoch 135/150
# 505/505 [==============================] - 0s 257us/step - loss: 0.0413 - accuracy: 0.9842
# Epoch 136/150
# 505/505 [==============================] - 0s 464us/step - loss: 0.0418 - accuracy: 0.9822
# Epoch 137/150
# 505/505 [==============================] - 0s 342us/step - loss: 0.0410 - accuracy: 0.9802
# Epoch 138/150
# 505/505 [==============================] - 0s 423us/step - loss: 0.0411 - accuracy: 0.9842
# Epoch 139/150
# 505/505 [==============================] - 0s 365us/step - loss: 0.0406 - accuracy: 0.9822
# Epoch 140/150
# 505/505 [==============================] - 0s 89us/step - loss: 0.0405 - accuracy: 0.9842
# Epoch 141/150
# 505/505 [==============================] - 0s 91us/step - loss: 0.0405 - accuracy: 0.9822
# Epoch 142/150
# 505/505 [==============================] - 0s 120us/step - loss: 0.0399 - accuracy: 0.9822
# Epoch 143/150
# 505/505 [==============================] - 0s 284us/step - loss: 0.0397 - accuracy: 0.9822
# Epoch 144/150
# 505/505 [==============================] - 0s 417us/step - loss: 0.0396 - accuracy: 0.9842
# Epoch 145/150
# 505/505 [==============================] - 0s 363us/step - loss: 0.0394 - accuracy: 0.9822
# Epoch 146/150
# 505/505 [==============================] - 0s 336us/step - loss: 0.0392 - accuracy: 0.9842
# Epoch 147/150
# 505/505 [==============================] - 0s 535us/step - loss: 0.0391 - accuracy: 0.9842
# Epoch 148/150
# 505/505 [==============================] - 0s 338us/step - loss: 0.0391 - accuracy: 0.9802
# Epoch 149/150
# 505/505 [==============================] - 0s 277us/step - loss: 0.0385 - accuracy: 0.9822
# Epoch 150/150
# 505/505 [==============================] - 0s 277us/step - loss: 0.0390 - accuracy: 0.9842
# 252/252 [==============================] - 0s 518us/step
# 505/505 [==============================] - 0s 41us/step
# Epoch 1/20
# 504/504 [==============================] - 0s 960us/step - loss: 1.0179 - accuracy: 0.5476
# Epoch 2/20
# 504/504 [==============================] - 0s 534us/step - loss: 0.7726 - accuracy: 0.7460
# Epoch 3/20
# 504/504 [==============================] - 0s 293us/step - loss: 0.5840 - accuracy: 0.8413
# Epoch 4/20
# 504/504 [==============================] - 0s 352us/step - loss: 0.4306 - accuracy: 0.8968
# Epoch 5/20
# 504/504 [==============================] - 0s 665us/step - loss: 0.2959 - accuracy: 0.9107
# Epoch 6/20
# 504/504 [==============================] - 0s 364us/step - loss: 0.2146 - accuracy: 0.9147
# Epoch 7/20
# 504/504 [==============================] - 0s 89us/step - loss: 0.1660 - accuracy: 0.9385
# Epoch 8/20
# 504/504 [==============================] - 0s 93us/step - loss: 0.1317 - accuracy: 0.9504
# Epoch 9/20
# ...
# Epoch 9/50
# 505/505 [==============================] - 0s 195us/step - loss: 0.3441 - accuracy: 0.8911
# Epoch 10/50
# 505/505 [==============================] - 0s 140us/step - loss: 0.3024 - accuracy: 0.8990
# Epoch 11/50
# 505/505 [==============================] - 0s 170us/step - loss: 0.2634 - accuracy: 0.9109
# Epoch 12/50
# 505/505 [==============================] - 0s 164us/step - loss: 0.2349 - accuracy: 0.9188
# Epoch 13/50
# 505/505 [==============================] - 0s 154us/step - loss: 0.2123 - accuracy: 0.9307
# Epoch 14/50
# 505/505 [==============================] - 0s 174us/step - loss: 0.1921 - accuracy: 0.9426
# Epoch 15/50
# 505/505 [==============================] - 0s 158us/step - loss: 0.1781 - accuracy: 0.9545
# Epoch 16/50
# 505/505 [==============================] - 0s 144us/step - loss: 0.1618 - accuracy: 0.9505
# Epoch 17/50
# 505/505 [==============================] - 0s 138us/step - loss: 0.1498 - accuracy: 0.9604
# Epoch 18/50
# 505/505 [==============================] - 0s 158us/step - loss: 0.1424 - accuracy: 0.9584
# Epoch 19/50
# 505/505 [==============================] - 0s 156us/step - loss: 0.1322 - accuracy: 0.9663
# Epoch 20/50
# 505/505 [==============================] - 0s 153us/step - loss: 0.1248 - accuracy: 0.9743
# Epoch 21/50
# 505/505 [==============================] - 0s 152us/step - loss: 0.1171 - accuracy: 0.9723
# Epoch 22/50
# 505/505 [==============================] - 0s 154us/step - loss: 0.1112 - accuracy: 0.9723
# Epoch 23/50
# 505/505 [==============================] - 0s 151us/step - loss: 0.1056 - accuracy: 0.9762
# Epoch 24/50
# 505/505 [==============================] - 0s 144us/step - loss: 0.1014 - accuracy: 0.9723
# Epoch 25/50
# 505/505 [==============================] - 0s 149us/step - loss: 0.1012 - accuracy: 0.9743
# Epoch 26/50
# 505/505 [==============================] - 0s 151us/step - loss: 0.0925 - accuracy: 0.9802
# Epoch 27/50
# 505/505 [==============================] - 0s 146us/step - loss: 0.0887 - accuracy: 0.9782
# Epoch 28/50
# 505/505 [==============================] - 0s 129us/step - loss: 0.0871 - accuracy: 0.9782
# Epoch 29/50
# 505/505 [==============================] - 0s 144us/step - loss: 0.0834 - accuracy: 0.9782
# Epoch 30/50
# 505/505 [==============================] - 0s 141us/step - loss: 0.0792 - accuracy: 0.9782
# Epoch 31/50
# 505/505 [==============================] - 0s 146us/step - loss: 0.0780 - accuracy: 0.9782
# Epoch 32/50
# 505/505 [==============================] - 0s 138us/step - loss: 0.0757 - accuracy: 0.9762
# Epoch 33/50
# 505/505 [==============================] - 0s 142us/step - loss: 0.0720 - accuracy: 0.9782
# Epoch 34/50
# 505/505 [==============================] - 0s 173us/step - loss: 0.0701 - accuracy: 0.9802
# Epoch 35/50
# 505/505 [==============================] - 0s 142us/step - loss: 0.0685 - accuracy: 0.9802
# Epoch 36/50
# 505/505 [==============================] - 0s 141us/step - loss: 0.0668 - accuracy: 0.9822
# Epoch 37/50
# 505/505 [==============================] - 0s 152us/step - loss: 0.0652 - accuracy: 0.9782
# Epoch 38/50
# 505/505 [==============================] - 0s 139us/step - loss: 0.0630 - accuracy: 0.9782
# Epoch 39/50
# 505/505 [==============================] - 0s 135us/step - loss: 0.0623 - accuracy: 0.9762
# Epoch 40/50
# 505/505 [==============================] - 0s 156us/step - loss: 0.0614 - accuracy: 0.9802
# Epoch 41/50
# 505/505 [==============================] - 0s 147us/step - loss: 0.0593 - accuracy: 0.9802
# Epoch 42/50
# 505/505 [==============================] - 0s 149us/step - loss: 0.0578 - accuracy: 0.9782
# Epoch 43/50
# 505/505 [==============================] - 0s 160us/step - loss: 0.0562 - accuracy: 0.9802
# Epoch 44/50
# 505/505 [==============================] - 0s 152us/step - loss: 0.0551 - accuracy: 0.9822
# Epoch 45/50
# 505/505 [==============================] - 0s 154us/step - loss: 0.0545 - accuracy: 0.9762
# Epoch 46/50
# 505/505 [==============================] - 0s 156us/step - loss: 0.0536 - accuracy: 0.9822
# Epoch 47/50
# 505/505 [==============================] - 0s 140us/step - loss: 0.0525 - accuracy: 0.9802
# Epoch 48/50
# 505/505 [==============================] - 0s 167us/step - loss: 0.0506 - accuracy: 0.9822
# Epoch 49/50
# 505/505 [==============================] - 0s 136us/step - loss: 0.0502 - accuracy: 0.9802
# Epoch 50/50
# 505/505 [==============================] - 0s 148us/step - loss: 0.0503 - accuracy: 0.9762
# 252/252 [==============================] - 0s 1ms/step
# 505/505 [==============================] - 0s 89us/step
# Epoch 1/10
# 504/504 [==============================] - 0s 956us/step - loss: 1.0573 - accuracy: 0.5833
# Epoch 2/10
# 504/504 [==============================] - 0s 55us/step - loss: 1.0126 - accuracy: 0.6567
# Epoch 3/10
# 504/504 [==============================] - 0s 43us/step - loss: 0.9667 - accuracy: 0.6587
# Epoch 4/10
# 504/504 [==============================] - 0s 50us/step - loss: 0.9227 - accuracy: 0.6627
# Epoch 5/10
# 504/504 [==============================] - 0s 55us/step - loss: 0.8813 - accuracy: 0.6528
# Epoch 6/10
# 504/504 [==============================] - 0s 65us/step - loss: 0.8437 - accuracy: 0.6290
# Epoch 7/10
# 504/504 [==============================] - 0s 55us/step - loss: 0.8113 - accuracy: 0.6190
# Epoch 8/10
# 504/504 [==============================] - 0s 49us/step - loss: 0.7830 - accuracy: 0.6171
# Epoch 9/10
# 504/504 [==============================] - 0s 55us/step - loss: 0.7575 - accuracy: 0.6151
# Epoch 10/10
# 504/504 [==============================] - 0s 55us/step - loss: 0.7343 - accuracy: 0.6190
# 253/253 [==============================] - 0s 1ms/step
# 504/504 [==============================] - 0s 40us/step
# Epoch 1/10
# 505/505 [==============================] - 0s 952us/step - loss: 1.0526 - accuracy: 0.4099
# Epoch 2/10
# 505/505 [==============================] - 0s 51us/step - loss: 1.0104 - accuracy: 0.4297
# Epoch 3/10
# 505/505 [==============================] - 0s 57us/step - loss: 0.9621 - accuracy: 0.4535
# Epoch 4/10
# 505/505 [==============================] - 0s 59us/step - loss: 0.9104 - accuracy: 0.5089
# Epoch 5/10
# 505/505 [==============================] - 0s 59us/step - loss: 0.8602 - accuracy: 0.6317
# Epoch 6/10
# 505/505 [==============================] - 0s 53us/step - loss: 0.8124 - accuracy: 0.7644
# Epoch 7/10
# 505/505 [==============================] - 0s 63us/step - loss: 0.7698 - accuracy: 0.8356
# Epoch 8/10
# 505/505 [==============================] - 0s 57us/step - loss: 0.7284 - accuracy: 0.8079
# Epoch 9/10
# 505/505 [==============================] - 0s 45us/step - loss: 0.6896 - accuracy: 0.7960
# Epoch 10/10
# 505/505 [==============================] - 0s 77us/step - loss: 0.6536 - accuracy: 0.7703
# 252/252 [==============================] - 0s 1ms/step
# 505/505 [==============================] - 0s 53us/step
# Epoch 1/10
# 505/505 [==============================] - 1s 1ms/step - loss: 1.0454 - accuracy: 0.3822
# Epoch 2/10
# 505/505 [==============================] - 0s 65us/step - loss: 1.0029 - accuracy: 0.4000
# Epoch 3/10
# 505/505 [==============================] - 0s 63us/step - loss: 0.9627 - accuracy: 0.4198
# Epoch 4/10
# 505/505 [==============================] - 0s 53us/step - loss: 0.9231 - accuracy: 0.4277
# Epoch 5/10
# 505/505 [==============================] - 0s 63us/step - loss: 0.8835 - accuracy: 0.4614
# Epoch 6/10
# 505/505 [==============================] - 0s 65us/step - loss: 0.8455 - accuracy: 0.4950
# Epoch 7/10
# 505/505 [==============================] - 0s 67us/step - loss: 0.8092 - accuracy: 0.5663
# Epoch 8/10
# 505/505 [==============================] - 0s 67us/step - loss: 0.7746 - accuracy: 0.6733
# Epoch 9/10
# 505/505 [==============================] - 0s 69us/step - loss: 0.7419 - accuracy: 0.7347
# Epoch 10/10
# 505/505 [==============================] - 0s 65us/step - loss: 0.7115 - accuracy: 0.8337
# 252/252 [==============================] - 0s 1ms/step
# 505/505 [==============================] - 0s 38us/step
# Epoch 1/80
# 757/757 [==============================] - 0s 638us/step - loss: 1.0943 - accuracy: 0.4254
# Epoch 2/80
# 757/757 [==============================] - 0s 55us/step - loss: 1.0376 - accuracy: 0.6407
# Epoch 3/80
# 757/757 [==============================] - 0s 50us/step - loss: 0.9863 - accuracy: 0.6764
# Epoch 4/80
# 757/757 [==============================] - 0s 46us/step - loss: 0.9314 - accuracy: 0.6816
# Epoch 5/80
# 757/757 [==============================] - 0s 45us/step - loss: 0.8724 - accuracy: 0.7226
# Epoch 6/80
# 757/757 [==============================] - 0s 47us/step - loss: 0.8125 - accuracy: 0.7609
# Epoch 7/80
# 757/757 [==============================] - 0s 49us/step - loss: 0.7564 - accuracy: 0.7913
# Epoch 8/80
# 757/757 [==============================] - 0s 58us/step - loss: 0.7047 - accuracy: 0.8177
# Epoch 9/80
# 757/757 [==============================] - 0s 52us/step - loss: 0.6564 - accuracy: 0.8362
# Epoch 10/80
# 757/757 [==============================] - 0s 50us/step - loss: 0.6109 - accuracy: 0.8468
# Epoch 11/80
# 757/757 [==============================] - 0s 50us/step - loss: 0.5657 - accuracy: 0.8547
# Epoch 12/80
# 757/757 [==============================] - 0s 54us/step - loss: 0.5214 - accuracy: 0.8679
# Epoch 13/80
# 757/757 [==============================] - 0s 49us/step - loss: 0.4787 - accuracy: 0.8758
# Epoch 14/80
# 757/757 [==============================] - 0s 49us/step - loss: 0.4388 - accuracy: 0.8904
# Epoch 15/80
# 757/757 [==============================] - 0s 55us/step - loss: 0.4022 - accuracy: 0.8956
# Epoch 16/80
# 757/757 [==============================] - 0s 45us/step - loss: 0.3705 - accuracy: 0.9022
# Epoch 17/80
# 757/757 [==============================] - 0s 43us/step - loss: 0.3417 - accuracy: 0.9036
# Epoch 18/80
# 757/757 [==============================] - 0s 53us/step - loss: 0.3155 - accuracy: 0.9128
# Epoch 19/80
# 757/757 [==============================] - 0s 51us/step - loss: 0.2937 - accuracy: 0.9168
# Epoch 20/80
# 757/757 [==============================] - 0s 51us/step - loss: 0.2739 - accuracy: 0.9207
# Epoch 21/80
# 757/757 [==============================] - 0s 47us/step - loss: 0.2589 - accuracy: 0.9168
# Epoch 22/80
# 757/757 [==============================] - 0s 47us/step - loss: 0.2428 - accuracy: 0.9247
# Epoch 23/80
# 757/757 [==============================] - 0s 62us/step - loss: 0.2280 - accuracy: 0.9260
# Epoch 24/80
# 757/757 [==============================] - 0s 44us/step - loss: 0.2146 - accuracy: 0.9339
# Epoch 25/80
# 757/757 [==============================] - 0s 48us/step - loss: 0.2035 - accuracy: 0.9379
# Epoch 26/80
# 757/757 [==============================] - 0s 55us/step - loss: 0.1932 - accuracy: 0.9472
# Epoch 27/80
# 757/757 [==============================] - 0s 59us/step - loss: 0.1831 - accuracy: 0.9577
# Epoch 28/80
# 757/757 [==============================] - 0s 53us/step - loss: 0.1747 - accuracy: 0.9590
# Epoch 29/80
# 757/757 [==============================] - 0s 54us/step - loss: 0.1650 - accuracy: 0.9630
# Epoch 30/80
# 757/757 [==============================] - 0s 54us/step - loss: 0.1562 - accuracy: 0.9604
# Epoch 31/80
# 757/757 [==============================] - 0s 68us/step - loss: 0.1475 - accuracy: 0.9657
# Epoch 32/80
# 757/757 [==============================] - 0s 55us/step - loss: 0.1410 - accuracy: 0.9643
# Epoch 33/80
# 757/757 [==============================] - 0s 53us/step - loss: 0.1336 - accuracy: 0.9683
# Epoch 34/80
# 757/757 [==============================] - 0s 47us/step - loss: 0.1272 - accuracy: 0.9696
# Epoch 35/80
# 757/757 [==============================] - 0s 51us/step - loss: 0.1211 - accuracy: 0.9709
# Epoch 36/80
# 757/757 [==============================] - 0s 51us/step - loss: 0.1163 - accuracy: 0.9749
# Epoch 37/80
# 757/757 [==============================] - 0s 54us/step - loss: 0.1115 - accuracy: 0.9749
# Epoch 38/80
# 757/757 [==============================] - 0s 47us/step - loss: 0.1074 - accuracy: 0.9762
# Epoch 39/80
# 757/757 [==============================] - 0s 60us/step - loss: 0.1041 - accuracy: 0.9736
# Epoch 40/80
# 757/757 [==============================] - 0s 53us/step - loss: 0.0999 - accuracy: 0.9762
# Epoch 41/80
# 757/757 [==============================] - 0s 57us/step - loss: 0.0963 - accuracy: 0.9802
# Epoch 42/80
# 757/757 [==============================] - 0s 51us/step - loss: 0.0930 - accuracy: 0.9789
# Epoch 43/80
# 757/757 [==============================] - 0s 55us/step - loss: 0.0908 - accuracy: 0.9775
# Epoch 44/80
# 757/757 [==============================] - 0s 65us/step - loss: 0.0885 - accuracy: 0.9789
# Epoch 45/80
# 757/757 [==============================] - 0s 42us/step - loss: 0.0853 - accuracy: 0.9789
# Epoch 46/80
# 757/757 [==============================] - 0s 59us/step - loss: 0.0827 - accuracy: 0.9789
# Epoch 47/80
# 757/757 [==============================] - 0s 54us/step - loss: 0.0800 - accuracy: 0.9815
# Epoch 48/80
# 757/757 [==============================] - 0s 57us/step - loss: 0.0785 - accuracy: 0.9802
# Epoch 49/80
# 757/757 [==============================] - 0s 57us/step - loss: 0.0759 - accuracy: 0.9828
# Epoch 50/80
# 757/757 [==============================] - 0s 50us/step - loss: 0.0751 - accuracy: 0.9815
# Epoch 51/80
# 757/757 [==============================] - 0s 58us/step - loss: 0.0745 - accuracy: 0.9802
# Epoch 52/80
# 757/757 [==============================] - 0s 51us/step - loss: 0.0717 - accuracy: 0.9802
# Epoch 53/80
# 757/757 [==============================] - 0s 63us/step - loss: 0.0693 - accuracy: 0.9828
# Epoch 54/80
# 757/757 [==============================] - 0s 72us/step - loss: 0.0680 - accuracy: 0.9828
# Epoch 55/80
# 757/757 [==============================] - 0s 43us/step - loss: 0.0663 - accuracy: 0.9828
# Epoch 56/80
# 757/757 [==============================] - 0s 46us/step - loss: 0.0652 - accuracy: 0.9828
# Epoch 57/80
# 757/757 [==============================] - 0s 53us/step - loss: 0.0639 - accuracy: 0.9828
# Epoch 58/80
# 757/757 [==============================] - 0s 50us/step - loss: 0.0639 - accuracy: 0.9815
# Epoch 59/80
# 757/757 [==============================] - 0s 53us/step - loss: 0.0617 - accuracy: 0.9828
# Epoch 60/80
# 757/757 [==============================] - 0s 55us/step - loss: 0.0608 - accuracy: 0.9841
# Epoch 61/80
# 757/757 [==============================] - 0s 57us/step - loss: 0.0602 - accuracy: 0.9802
# Epoch 62/80
# 757/757 [==============================] - 0s 54us/step - loss: 0.0592 - accuracy: 0.9868
# Epoch 63/80
# 757/757 [==============================] - 0s 51us/step - loss: 0.0572 - accuracy: 0.9828
# Epoch 64/80
# 757/757 [==============================] - 0s 50us/step - loss: 0.0570 - accuracy: 0.9841
# Epoch 65/80
# 757/757 [==============================] - 0s 55us/step - loss: 0.0563 - accuracy: 0.9828
# Epoch 66/80
# 757/757 [==============================] - 0s 49us/step - loss: 0.0553 - accuracy: 0.9815
# Epoch 67/80
# 757/757 [==============================] - 0s 54us/step - loss: 0.0543 - accuracy: 0.9855
# Epoch 68/80
# 757/757 [==============================] - 0s 51us/step - loss: 0.0535 - accuracy: 0.9841
# Epoch 69/80
# 757/757 [==============================] - 0s 50us/step - loss: 0.0540 - accuracy: 0.9815
# Epoch 70/80
# 757/757 [==============================] - 0s 51us/step - loss: 0.0522 - accuracy: 0.9868
# Epoch 71/80
# 757/757 [==============================] - 0s 45us/step - loss: 0.0512 - accuracy: 0.9828
# Epoch 72/80
# 757/757 [==============================] - 0s 53us/step - loss: 0.0508 - accuracy: 0.9815
# Epoch 73/80
# 757/757 [==============================] - 0s 50us/step - loss: 0.0499 - accuracy: 0.9868
# Epoch 74/80
# 757/757 [==============================] - 0s 47us/step - loss: 0.0502 - accuracy: 0.9828
# Epoch 75/80
# 757/757 [==============================] - 0s 51us/step - loss: 0.0494 - accuracy: 0.9855
# Epoch 76/80
# 757/757 [==============================] - 0s 54us/step - loss: 0.0484 - accuracy: 0.9841
# Epoch 77/80
# 757/757 [==============================] - 0s 54us/step - loss: 0.0476 - accuracy: 0.9855
# Epoch 78/80
# 757/757 [==============================] - 0s 57us/step - loss: 0.0473 - accuracy: 0.9828
# Epoch 79/80
# 757/757 [==============================] - 0s 53us/step - loss: 0.0465 - accuracy: 0.9841
# Epoch 80/80
# 757/757 [==============================] - 0s 65us/step - loss: 0.0460 - accuracy: 0.9841
# Randomized search time: 433.13308119773865

# %%
print("Best Score: ",
      random_search.best_score_,
      "and Best Params: ",
      random_search.best_params_)
# Out:
# Best Score:  -0.2953436300256923 and Best Params:  {'learning_rate': 0.001, 'epochs': 80, 'batch_size': 64, 'activation': 'relu'}

# %%
from keras.models import Sequential
from keras import layers

input_dim = X_train[all_col].shape[1]  # Number of features

model = Sequential()
model.add(layers.Dense(10, input_dim=input_dim, activation='relu'))
model.add(layers.Dense(3, activation='sigmoid'))

opt = Adam(learning_rate = 0.001)

model.compile(loss='categorical_crossentropy', 
               optimizer=opt, 
               metrics=['accuracy'])
model.summary()

history = model.fit(X_train[all_col], to_categorical(y_train),
                     epochs=80,
                     verbose=False,
                     validation_data=(X_valid[all_col], to_categorical(y_valid)),
                     batch_size=64)

loss, accuracy = model.evaluate(X_train[all_col], to_categorical(y_train), verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(X_valid[all_col], to_categorical(y_valid), verbose=False)
print("Valid Accuracy:  {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(X_test[all_col], to_categorical(y_test), verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))

import matplotlib.pyplot as plt
plt.style.use('ggplot')

def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'b', label='Training acc')
    plt.plot(x, val_acc, 'r', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

plot_history(history)
# Out:
# Model: "sequential_70"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_139 (Dense)            (None, 10)                7030
# _________________________________________________________________
# dense_140 (Dense)            (None, 3)                 33
# =================================================================
# Total params: 7,063
# Trainable params: 7,063
# Non-trainable params: 0
# _________________________________________________________________
# Training Accuracy: 0.9855
# Valid Accuracy:  0.9421
# Testing Accuracy:  0.9072

# %% [markdown]
# # Model Evaluation: Test Data

# %%
score, acc = model.evaluate(X_test[all_col], to_categorical(y_test),
                       batch_size=16, verbose=2)

print('Test accuracy:', acc)
# Out:
# Test accuracy: 0.9071729779243469

# %%
text_labels = le.classes_
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    # print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')


y_pred = pd.DataFrame(model.predict_classes(X_test[all_col]));
cnf_matrix = confusion_matrix(y_test, y_pred)

# Plot normalized confusion matrix
fig = plt.figure()
fig.set_size_inches(7, 6, forward=True)
#fig.align_labels()

# fig.subplots_adjust(left=0.0, right=1.0, bottom=0.0, top=1.0)
plot_confusion_matrix(cnf_matrix, classes=np.asarray(text_labels), normalize=False,
                      title='Confusion matrix')

fig.savefig("txt_classification_NN_BOW" + ".png", pad_inches=5.0)
# Out:
# Confusion matrix, without normalization

# %%
from sklearn.metrics import cohen_kappa_score
cohen_score = cohen_kappa_score(y_test, y_pred)
cohen_score
# Out:
# 0.8156098596032111

# %%
from sklearn.metrics import precision_recall_fscore_support as score

precision, recall, fscore, support = score(y_test, y_pred)


score_dic= {'Labels':text_labels,
           'precision':precision,
            'recall':recall,
            'fscore':fscore,
            'support':support
           }

pd.DataFrame(score_dic)
# Out:
#                       Labels  precision    recall    fscore  support
# 0  Cof/ Arabica Green Coffee   0.937984  0.902985  0.920152      134
# 1  Cof/ Robusta Green Coffee   0.867925  0.920000  0.893204      100
# 2                     OTHERS   1.000000  0.666667  0.800000        3

# %%
tmp = pd.DataFrame(data = cnf_matrix,index = text_labels, columns = text_labels)
tmp["total"] = tmp.sum(axis=1)
accuracy= {"Category":[],"Accuracy":[]}
for i in range(tmp.shape[0]):
    accuracy["Category"].append(tmp.index[i])
    accuracy["Accuracy"].append(tmp.iloc[i,i]/tmp.loc[tmp.index[i],"total"])

print("Accuracy:")
print(pd.DataFrame(accuracy))
# Out:
# Accuracy:
#                     Category  Accuracy
# 0  Cof/ Arabica Green Coffee  0.902985
# 1  Cof/ Robusta Green Coffee  0.920000
# 2                     OTHERS  0.666667

# %%
from sklearn.metrics import roc_curve, auc
from scipy import interp
from itertools import cycle

num_labels = 3
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(num_labels):
    fpr[i], tpr[i], _ = roc_curve((y_test==i), (y_pred == i))
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(to_categorical(y_test).ravel(), to_categorical(y_pred).ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(num_labels)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(num_labels):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= num_labels

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
fig = plt.figure()
fig.set_size_inches(7, 6, forward=True)
# plt.figure()
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(num_labels), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of {0} (area = {1:0.2f})'
             ''.format(text_labels[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score

# For each class
precision = dict()
recall = dict()
average_precision = dict()
for i in range(num_labels):
    precision[i], recall[i], _ = precision_recall_curve((y_test==i), (y_pred == i))
    average_precision[i] = average_precision_score((y_test==i), (y_pred == i))

# A "micro-average": quantifying score on all classes jointly
precision["micro"], recall["micro"], _ = precision_recall_curve(to_categorical(y_test).ravel(), to_categorical(y_pred).ravel())
average_precision["micro"] = average_precision_score(to_categorical(y_test), to_categorical(y_pred),
                                                     average="micro")
print('Average precision score, micro-averaged over all classes: {0:0.2f}'
      .format(average_precision["micro"]))
# Out:
# Average precision score, micro-averaged over all classes: 0.85

# %%
plt.figure()
plt.step(recall['micro'], precision['micro'], color='b', alpha=0.2,
         where='post')
plt.fill_between(recall["micro"], precision["micro"], alpha=0.2, color='b')#,
                 #**step_kwargs)

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title(
    'Average precision score, micro-averaged over all classes: AP={0:0.2f}'
    .format(average_precision["micro"]))
# Out:
# Text(0.5, 1.0, 'Average precision score, micro-averaged over all classes: AP=0.85')

# %%
from itertools import cycle
# setup plot details
colors = cycle(['navy', 'turquoise', 'darkorange', 'cornflowerblue', 'teal'])

plt.figure(figsize=(8, 8))
f_scores = np.linspace(0.2, 0.8, num=4)
lines = []
labels = []
for f_score in f_scores:
    x = np.linspace(0.01, 1)
    y = f_score * x / (2 * x - f_score)
    l, = plt.plot(x[y >= 0], y[y >= 0], color='gray', alpha=0.2)
    plt.annotate('f1={0:0.1f}'.format(f_score), xy=(0.9, y[45] + 0.02))

lines.append(l)
labels.append('iso-f1 curves')
l, = plt.plot(recall["micro"], precision["micro"], color='gold', lw=2)
lines.append(l)
labels.append('micro-average Precision-recall (area = {0:0.2f})'
              ''.format(average_precision["micro"]))

for i, color in zip(range(num_labels), colors):
    l, = plt.plot(recall[i], precision[i], color=color, lw=2)
    lines.append(l)
    labels.append('Precision-recall for class:{0} (area = {1:0.2f})'
                  ''.format(text_labels[i], average_precision[i]))

fig = plt.gcf()
fig.subplots_adjust(bottom=0.25)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall curve to multi-class')
plt.legend(lines, labels, loc=(0, -.2), prop=dict(size=10))


plt.show()
